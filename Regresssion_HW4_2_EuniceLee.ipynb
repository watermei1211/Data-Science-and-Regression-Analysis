# %% [markdown]
# 學號：0111109069 姓名：李佳毓\
# 作業題目：上傳上課時分類練習的程式，以及w5影片的程式\
# 繳交期限：2022-10-15 09:30

# %% [markdown]
# # Hyperparameter Tuning

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data

# %%
np.random.seed(1)
m = 500
x1 = 5 * np.random.rand(m,1) - 3
y = 10 + (2 * x1) + x1**2 + 2 * x1**3 + 10 * np.random.randn(m,1)

# %%
plt.figure(figsize=(3,2))
plt.plot(x1 , y, "b.", markersize = 1)
plt.xlabel("$x_1$", fontsize = 18)
plt.ylabel("y", rotation=0, fontsize = 18)
plt.show()

# %% [markdown]
# ## Split Training / Test Sets

# %%
from sklearn.model_selection import train_test_split

x1_train, x1_test, y_train, y_test = train_test_split(x1, y, test_size=0.2, random_state=1)

# %% [markdown]
# ## 建構 Pipeline

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import SGDRegressor

# %%
pip_reg = Pipeline([
    ('poly', PolynomialFeatures(include_bias=False)),
    ('scal', StandardScaler()),
    ('sgd', SGDRegressor(penalty='elasticnet', random_state=1))
])

# %% [markdown]
# ## Grid Search

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = [{
    'poly__degree':[2, 3, 4],
    'sgd__alpha': [0.1, 1, 10],
    'sgd__l1_ratio': [0, 0.5, 1]
}]

# %%
grid_search = GridSearchCV(pip_reg, param_grid, scoring='r2',
                          return_train_score=True, cv=3)

grid_search.fit(x1_train, y_train.ravel())
# Out:
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('poly',
#                                         PolynomialFeatures(include_bias=False)),
#                                        ('scal', StandardScaler()),
#                                        ('sgd',
#                                         SGDRegressor(penalty='elasticnet',
#                                                      random_state=1))]),
#              param_grid=[{'poly__degree': [2, 3, 4], 'sgd__alpha': [0.1, 1, 10],
#                           'sgd__l1_ratio': [0, 0.5, 1]}],
#              return_train_score=True, scoring='r2')

# %% [markdown]
# ## 最佳超參數與模型

# %%
grid_search.best_score_
# Out:
# 0.7329379166794469

# %%
grid_search.best_params_
# Out:
# {'poly__degree': 3, 'sgd__alpha': 0.1, 'sgd__l1_ratio': 1}

# %%
grid_model = grid_search.best_estimator_

grid_model.score(x1_test, y_test)
# Out:
# 0.7287417714648952

# %% [markdown]
# ## 搜尋結果列表

# %%
grid_rlt = grid_search.cv_results_
for mean_score, params in zip(grid_rlt['mean_test_score'],
                               grid_rlt['params']):
    print(mean_score, params)
# Out:
# 0.6709144714185259 {'poly__degree': 2, 'sgd__alpha': 0.1, 'sgd__l1_ratio': 0}
# 0.6729631263131383 {'poly__degree': 2, 'sgd__alpha': 0.1, 'sgd__l1_ratio': 0.5}
# 0.6739838341338239 {'poly__degree': 2, 'sgd__alpha': 0.1, 'sgd__l1_ratio': 1}
# 0.5604173544087145 {'poly__degree': 2, 'sgd__alpha': 1, 'sgd__l1_ratio': 0}
# 0.6191871577349027 {'poly__degree': 2, 'sgd__alpha': 1, 'sgd__l1_ratio': 0.5}
# 0.6703784468578063 {'poly__degree': 2, 'sgd__alpha': 1, 'sgd__l1_ratio': 1}
# 0.14710596880018803 {'poly__degree': 2, 'sgd__alpha': 10, 'sgd__l1_ratio': 0}
# 0.17066184581085764 {'poly__degree': 2, 'sgd__alpha': 10, 'sgd__l1_ratio': 0.5}
# 0.35965297018820436 {'poly__degree': 2, 'sgd__alpha': 10, 'sgd__l1_ratio': 1}
# 0.724812436785547 {'poly__degree': 3, 'sgd__alpha': 0.1, 'sgd__l1_ratio': 0}
# 0.7292732003307676 {'poly__degree': 3, 'sgd__alpha': 0.1, 'sgd__l1_ratio': 0.5}
# 0.7329379166794469 {'poly__degree': 3, 'sgd__alpha': 0.1, 'sgd__l1_ratio': 1}
# 0.6498673294136279 {'poly__degree': 3, 'sgd__alpha': 1, 'sgd__l1_ratio': 0}
# 0.6859505846276267 {'poly__degree': 3, 'sgd__alpha': 1, 'sgd__l1_ratio': 0.5}
# 0.7289761620214938 {'poly__degree': 3, 'sgd__alpha': 1, 'sgd__l1_ratio': 1}
# 0.23721593281131378 {'poly__degree': 3, 'sgd__alpha': 10, 'sgd__l1_ratio': 0}
# 0.2653131802701982 {'poly__degree': 3, 'sgd__alpha': 10, 'sgd__l1_ratio': 0.5}
# 0.44815218715540467 {'poly__degree': 3, 'sgd__alpha': 10, 'sgd__l1_ratio': 1}
# 0.7252860798521007 {'poly__degree': 4, 'sgd__alpha': 0.1, 'sgd__l1_ratio': 0}
# 0.7275918575750334 {'poly__degree': 4, 'sgd__alpha': 0.1, 'sgd__l1_ratio': 0.5}
# 0.7309052081280737 {'poly__degree': 4, 'sgd__alpha': 0.1, 'sgd__l1_ratio': 1}
# 0.6602795772347051 {'poly__degree': 4, 'sgd__alpha': 1, 'sgd__l1_ratio': 0}
# 0.6899897122464665 {'poly__degree': 4, 'sgd__alpha': 1, 'sgd__l1_ratio': 0.5}
# 0.7255102599812439 {'poly__degree': 4, 'sgd__alpha': 1, 'sgd__l1_ratio': 1}
# 0.27388634312557036 {'poly__degree': 4, 'sgd__alpha': 10, 'sgd__l1_ratio': 0}
# 0.3044163955485773 {'poly__degree': 4, 'sgd__alpha': 10, 'sgd__l1_ratio': 0.5}
# 0.4530244940075357 {'poly__degree': 4, 'sgd__alpha': 10, 'sgd__l1_ratio': 1}

# %%
import pandas as pd

pd.DataFrame(grid_search.cv_results_)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.002983      0.000824         0.000664        0.000470
# 1        0.001996      0.000030         0.000000        0.000000
# 2        0.002005      0.000811         0.000664        0.000470
# 3        0.001324      0.000466         0.000340        0.000481
# 4        0.002004      0.000014         0.000000        0.000000
# 5        0.001662      0.000472         0.000689        0.000487
# 6        0.001342      0.000480         0.000669        0.000473
# 7        0.001007      0.000013         0.000332        0.000470
# 8        0.000995      0.000005         0.000651        0.000460
# 9        0.001989      0.000007         0.000337        0.000477
# 10       0.002325      0.000470         0.000333        0.000470
# 11       0.002372      0.000876         0.000333        0.000470
# 12       0.000000      0.000000         0.000000        0.000000
# 13       0.005232      0.007399         0.000000        0.000000
# 14       0.000000      0.000000         0.000000        0.000000
# 15       0.004181      0.005912         0.000000        0.000000
# 16       0.000000      0.000000         0.000000        0.000000
# 17       0.000000      0.000000         0.000000        0.000000
# 18       0.000000      0.000000         0.000000        0.000000
# 19       0.000000      0.000000         0.000000        0.000000
# 20       0.000000      0.000000         0.005209        0.007366
# 21       0.000000      0.000000         0.005194        0.007345
# 22       0.000000      0.000000         0.000000        0.000000
# 23       0.005206      0.007363         0.003170        0.004482
# 24       0.002168      0.003066         0.000000        0.000000
# 25       0.000000      0.000000         0.000000        0.000000
# 26       0.000000      0.000000         0.000000        0.000000
#
#    param_poly__degree param_sgd__alpha param_sgd__l1_ratio  \
# 0                   2              0.1                   0
# 1                   2              0.1                 0.5
# 2                   2              0.1                   1
# 3                   2                1                   0
# 4                   2                1                 0.5
# 5                   2                1                   1
# 6                   2               10                   0
# 7                   2               10                 0.5
# 8                   2               10                   1
# 9                   3              0.1                   0
# 10                  3              0.1                 0.5
# 11                  3              0.1                   1
# 12                  3                1                   0
# 13                  3                1                 0.5
# 14                  3                1                   1
# 15                  3               10                   0
# 16                  3               10                 0.5
# 17                  3               10                   1
# 18                  4              0.1                   0
# 19                  4              0.1                 0.5
# 20                  4              0.1                   1
# 21                  4                1                   0
# 22                  4                1                 0.5
# 23                  4                1                   1
# 24                  4               10                   0
# 25                  4               10                 0.5
# 26                  4               10                   1
#
#                                                params  split0_test_score  \
# 0   {'poly__degree': 2, 'sgd__alpha': 0.1, 'sgd__l...           0.681827
# 1   {'poly__degree': 2, 'sgd__alpha': 0.1, 'sgd__l...           0.685450
# 2   {'poly__degree': 2, 'sgd__alpha': 0.1, 'sgd__l...           0.688785
# 3   {'poly__degree': 2, 'sgd__alpha': 1, 'sgd__l1_...           0.557087
# 4   {'poly__degree': 2, 'sgd__alpha': 1, 'sgd__l1_...           0.623108
# 5   {'poly__degree': 2, 'sgd__alpha': 1, 'sgd__l1_...           0.682686
# 6   {'poly__degree': 2, 'sgd__alpha': 10, 'sgd__l1...           0.134789
# 7   {'poly__degree': 2, 'sgd__alpha': 10, 'sgd__l1...           0.157878
# 8   {'poly__degree': 2, 'sgd__alpha': 10, 'sgd__l1...           0.360628
# 9   {'poly__degree': 3, 'sgd__alpha': 0.1, 'sgd__l...           0.735321
# 10  {'poly__degree': 3, 'sgd__alpha': 0.1, 'sgd__l...           0.740248
# 11  {'poly__degree': 3, 'sgd__alpha': 0.1, 'sgd__l...           0.743372
# 12  {'poly__degree': 3, 'sgd__alpha': 1, 'sgd__l1_...           0.646186
# 13  {'poly__degree': 3, 'sgd__alpha': 1, 'sgd__l1_...           0.690547
# 14  {'poly__degree': 3, 'sgd__alpha': 1, 'sgd__l1_...           0.737946
# 15  {'poly__degree': 3, 'sgd__alpha': 10, 'sgd__l1...           0.219359
# 16  {'poly__degree': 3, 'sgd__alpha': 10, 'sgd__l1...           0.246825
# 17  {'poly__degree': 3, 'sgd__alpha': 10, 'sgd__l1...           0.443157
# 18  {'poly__degree': 4, 'sgd__alpha': 0.1, 'sgd__l...           0.732367
# 19  {'poly__degree': 4, 'sgd__alpha': 0.1, 'sgd__l...           0.735835
# 20  {'poly__degree': 4, 'sgd__alpha': 0.1, 'sgd__l...           0.741885
# 21  {'poly__degree': 4, 'sgd__alpha': 1, 'sgd__l1_...           0.658552
# 22  {'poly__degree': 4, 'sgd__alpha': 1, 'sgd__l1_...           0.691865
# 23  {'poly__degree': 4, 'sgd__alpha': 1, 'sgd__l1_...           0.731410
# 24  {'poly__degree': 4, 'sgd__alpha': 10, 'sgd__l1...           0.262994
# 25  {'poly__degree': 4, 'sgd__alpha': 10, 'sgd__l1...           0.280828
# 26  {'poly__degree': 4, 'sgd__alpha': 10, 'sgd__l1...           0.442812
#
#     split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 0            0.620079           0.710837         0.670914        0.037847
# 1            0.619078           0.714362         0.672963        0.039889
# 2            0.616186           0.716980         0.673984        0.042459
# 3            0.541118           0.583047         0.560417        0.017278
# 4            0.588549           0.645905         0.619187        0.023579
# 5            0.618728           0.709721         0.670378        0.038153
# 6            0.179652           0.126876         0.147106        0.023239
# 7            0.208528           0.145580         0.170662        0.027242
# 8            0.406270           0.312062         0.359653        0.038466
# 9            0.667060           0.772056         0.724812        0.043504
# 10           0.669018           0.778554         0.729273        0.045386
# 11           0.670074           0.785368         0.732938        0.047643
# 12           0.612463           0.690953         0.649867        0.032149
# 13           0.640158           0.727147         0.685951        0.035661
# 14           0.670800           0.778183         0.728976        0.044296
# 15           0.265959           0.226329         0.237216        0.020523
# 16           0.299052           0.250062         0.265313        0.023894
# 17           0.468685           0.432614         0.448152        0.015144
# 18           0.668840           0.774651         0.725286        0.043486
# 19           0.669819           0.777121         0.727592        0.044192
# 20           0.669358           0.781473         0.730905        0.046424
# 21           0.612826           0.709461         0.660280        0.039470
# 22           0.642276           0.735828         0.689990        0.038215
# 23           0.669255           0.775866         0.725510        0.043723
# 24           0.273958           0.284707         0.273886        0.008865
# 25           0.336057           0.296364         0.304416        0.023255
# 26           0.468889           0.447373         0.453024        0.011371
#
#     rank_test_score  split0_train_score  split1_train_score  \
# 0                13            0.677307            0.708229
# 1                12            0.679451            0.710540
# 2                11            0.680708            0.711576
# 3                18            0.567911            0.600991
# 4                17            0.628831            0.657883
# 5                14            0.677798            0.709030
# 6                27            0.160548            0.201993
# 7                26            0.183041            0.232322
# 8                21            0.377901            0.438099
# 9                 8            0.734500            0.764145
# 10                3            0.739765            0.770133
# 11                1            0.742423            0.776841
# 12               16            0.655834            0.687767
# 13               10            0.696293            0.721557
# 14                4            0.739599            0.769304
# 15               25            0.244802            0.299046
# 16               24            0.271815            0.334758
# 17               20            0.466105            0.526562
# 18                7            0.736864            0.764515
# 19                5            0.739739            0.768986
# 20                2            0.745638            0.773149
# 21               15            0.672039            0.691854
# 22                9            0.701925            0.725516
# 23                6            0.734340            0.766635
# 24               23            0.289478            0.312472
# 25               22            0.306988            0.381565
# 26               19            0.465599            0.526249
#
#     split2_train_score  mean_train_score  std_train_score
# 0             0.655283          0.680273         0.021717
# 1             0.657430          0.682474         0.021787
# 2             0.658440          0.683575         0.021787
# 3             0.548605          0.572502         0.021632
# 4             0.602874          0.629863         0.022469
# 5             0.654674          0.680501         0.022273
# 6             0.153779          0.172107         0.021313
# 7             0.171025          0.195463         0.026521
# 8             0.328350          0.381450         0.044875
# 9             0.705448          0.734697         0.023963
# 10            0.709599          0.739832         0.024713
# 11            0.713653          0.744306         0.025831
# 12            0.636709          0.660103         0.021062
# 13            0.668577          0.695476         0.021637
# 14            0.708109          0.739004         0.024986
# 15            0.236731          0.260193         0.027671
# 16            0.257762          0.288111         0.033479
# 17            0.411153          0.467940         0.047133
# 18            0.705293          0.735557         0.024195
# 19            0.707105          0.738610         0.025276
# 20            0.710343          0.743043         0.025706
# 21            0.646377          0.670090         0.018617
# 22            0.671637          0.699693         0.022052
# 23            0.706309          0.735761         0.024649
# 24            0.280487          0.294145         0.013469
# 25            0.291679          0.326744         0.039265
# 26            0.423318          0.471722         0.042244

# %% [markdown]
# ## Plot model

# %%
plt.figure(figsize=(3, 2))

x1s = np.linspace(x1.min(),x1.max(),100).reshape(-1,1)
y_pred = grid_model.predict(x1s)

plt.plot(x1, y, "b.", markersize=1)
plt.plot(x1s, y_pred, "r-", linewidth=1, label="$\hat y$")

plt.xlabel("$x_1", fontsize = 18)
plt.ylabel("y", rotation = 0, fontsize = 18 )
plt.legend(loc="upper left", fontsize = 12 )

plt.show()

# %% [markdown]
# # Random Search

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
param_rnd = [{
    'poly__degree': range(1, 11, 1),
    'sgd__alpha': np.random.rand(100),
    'sgd__l1_ratio': np.random.rand(100)
}]

# %%
rnd_search = RandomizedSearchCV(pip_reg, 
    param_distributions=param_rnd, n_iter=10, cv=3,
    scoring='r2', random_state=1)

rnd_search.fit(x1_train, y_train.ravel())
# Out:
# RandomizedSearchCV(cv=3,
#                    estimator=Pipeline(steps=[('poly',
#                                               PolynomialFeatures(include_bias=False)),
#                                              ('scal', StandardScaler()),
#                                              ('sgd',
#                                               SGDRegressor(penalty='elasticnet',
#                                                            random_state=1))]),
#                    param_distributions=[{'poly__degree': range(1, 11),
#                                          'sgd__alpha': array([2.33768693e-01, 1.76678893e-01, 3.91099123e-01, 3.20564654e-01,
#        8.15476929e-01, 6.13525900e-01, 7.60001...
#        0.16744186, 0.26313902, 0.07161028, 0.97867281, 0.2363841 ,
#        0.66059836, 0.0896307 , 0.21077094, 0.50282438, 0.10495367,
#        0.3888734 , 0.53798772, 0.33920418, 0.55590021, 0.53676832,
#        0.3906105 , 0.69627008, 0.67848245, 0.68730315, 0.56149126,
#        0.35807991, 0.61311234, 0.93573627, 0.59688852, 0.97959017,
#        0.44100662, 0.73961196, 0.03760388, 0.76472664, 0.51828158])}],
#                    random_state=1, scoring='r2')

# %% [markdown]
# ## 最佳超參數與模型

# %%
rnd_search.best_score_
# Out:
# 0.7290606257660522

# %%
rnd_search.best_params_
# Out:
# {'sgd__l1_ratio': 0.8369977822135122,
#  'sgd__alpha': 0.18846839966641848,
#  'poly__degree': 8}

# %%
rnd_model = rnd_search.best_estimator_

rnd_model.score(x1_test, y_test)
# Out:
# 0.7194120839707838

# %%
rnd_rlt = rnd_search.cv_results_
for mean_score, params in zip(rnd_rlt['mean_test_score'],
                             rnd_rlt['params']):
    print(mean_score, params)
# Out:
# 0.7189314645551615 {'sgd__l1_ratio': 0.3473694203728128, 'sgd__alpha': 0.3092463846587796, 'poly__degree': 10}
# 0.7290606257660522 {'sgd__l1_ratio': 0.8369977822135122, 'sgd__alpha': 0.18846839966641848, 'poly__degree': 8}
# 0.6245037047380495 {'sgd__l1_ratio': 0.9357362666081998, 'sgd__alpha': 0.1978327846479193, 'poly__degree': 1}
# 0.6987319145017971 {'sgd__l1_ratio': 0.5370071168405407, 'sgd__alpha': 0.9742126278950913, 'poly__degree': 10}
# 0.7240949688839109 {'sgd__l1_ratio': 0.404001609054379, 'sgd__alpha': 0.23376869260410593, 'poly__degree': 6}
# 0.7070408387869961 {'sgd__l1_ratio': 0.6043068436688722, 'sgd__alpha': 0.8709456091610533, 'poly__degree': 8}
# 0.7178596810323777 {'sgd__l1_ratio': 0.7802245796913637, 'sgd__alpha': 0.688845259018665, 'poly__degree': 3}
# 0.7069534333029809 {'sgd__l1_ratio': 0.36598334666965426, 'sgd__alpha': 0.5834063146082279, 'poly__degree': 10}
# 0.7135013371763446 {'sgd__l1_ratio': 0.7441359213695352, 'sgd__alpha': 0.7600017523497489, 'poly__degree': 3}
# 0.7036069364896522 {'sgd__l1_ratio': 0.49288087343132025, 'sgd__alpha': 0.8730943782696405, 'poly__degree': 5}
